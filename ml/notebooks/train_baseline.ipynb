# %% [markdown]
# # RazorGuard X — baseline training notebook
# Prefer `python ml/training/train_baseline.py` for a reproducible CLI run.

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parents[1] / 'backend'))
from app.ml.train import train_and_save
train_and_save(n_samples=4000)
